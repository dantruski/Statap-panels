# %%
import os
import random
import re
import string

import nltk
import numpy as np
import pandas as pd

from gensim.models import Word2Vec

from nltk import word_tokenize
from nltk.corpus import stopwords


from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

nltk.download("stopwords")
nltk.download("punkt")

SEED = 42
random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
np.random.seed(SEED)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/daniel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/daniel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def clean_text(text, tokenizer, stopwords):
    """Pre-process text and generate tokens
    """
    text = str(text).lower()  # Lowercase words
    text = re.sub(r"\[(.*?)\]", "", text)  # Remove [+XYZ chars] in content
    text = re.sub(r"\s+", " ", text)  # Remove multiple spaces in content
    text = re.sub(r"\w+…|…", "", text)  # Remove ellipsis (and last word)
    text = re.sub(r"(?<=\w)-(?=\w)", " ", text)  # Replace dash between words
    text = re.sub(
        f"[{re.escape(string.punctuation)}]", "", text
    )  # Remove punctuation

    tokens = tokenizer(text)  # Get tokens from text
    tokens = [t for t in tokens if not t in stopwords]  # Remove stopwords
    tokens = ["" if t.isdigit() else t for t in tokens]  # Remove digits
    tokens = [t for t in tokens if len(t) > 1]  # Remove short tokens
    return tokens

# %%
df_raw = pd.read_json("/Users/daniel/Desktop/STATAPP/Statap-panels/temp_dataset.json")
df = df_raw.copy()
for col in text_columns:
    df[col] = df[col].astype(str).fillna("")

# Combine all text fields into a single text column
df["text"] = df[text_columns].apply(lambda x: " | ".join(x), axis=1)
df.head()
# Out:
#                                              history  \
# 0  [{'role': 'user', 'content': 'What are the mai...
# 1  [{'role': 'user', 'content': 'What is employee...
# 2  [{'role': 'user', 'content': 'Where is the hea...
# 3  [{'role': 'user', 'content': 'What happens whe...
# 4  [{'role': 'user', 'content': 'How can I instal...
#
#                                             question  \
# 0           What other sectors are they involved in?
# 1  How did it help against Vincent Bolloré's atte...
# 2              And what about Bouygues Construction?
# 3       How much money does this generate in France?
# 4                        Is there any cost involved?
#
#                              query_modifier_question  \
# 0  What other sectors is Bouygues involved in bes...
# 1  How did employee shareholding at Bouygues help...
# 2  Where is the headquarters of Bouygues Construc...
# 3  How much money do search engines earn from spo...
# 4  Is there any cost involved in installing Lilo ...
#
#                                     generated_answer  \
# 0  Besides construction, real estate, media, and ...
# 1  In 1998, Bouygues' employee shareholding helpe...
# 2  The headquarters of Bouygues Construction, kno...
# 3  Search engines in France earn approximately 2....
# 4  Not enough information is available about the ...
#
#                                               answer  \
# 0  Besides construction and real estate, Bouygues...
# 1  The employee shareholding helped counter Vince...
# 2  The headquarters of Bouygues Construction, kno...
# 3  In France, this generates about 2.4 billion eu...
# 4  No, using Lilo in a business setting is simple...
#
#                                                 text
# 0  [{'role': 'user', 'content': 'What are the mai...
# 1  [{'role': 'user', 'content': 'What is employee...
# 2  [{'role': 'user', 'content': 'Where is the hea...
# 3  [{'role': 'user', 'content': 'What happens whe...
# 4  [{'role': 'user', 'content': 'How can I instal...

# %%
# Define stopwords (use sklearn's built-in stopwords)
custom_stopwords = set(ENGLISH_STOP_WORDS) | {"history", "question", "query", "answer"}

# Tokenization and cleaning function (without NLTK)
def clean_and_tokenize(text):
    tokens = text.lower().split()  # Lowercase & split on whitespace
    tokens = [word for word in tokens if word.isalnum() and word not in custom_stopwords]  # Remove punctuation & stopwords
    return tokens

# Apply tokenization without using nltk
df["tokens"] = df["text"].astype(str).apply(clean_and_tokenize)

# Print dataset sizes
print(f"Original dataframe: {df_raw.shape}")
print(f"Pre-processed dataframe: {df.shape}")
# Out:
# Original dataframe: (144, 5)
# Pre-processed dataframe: (144, 7)

# %%
w2v_model = Word2Vec(sentences=df["tokens"], vector_size=100, window=5, min_count=2, workers=4)

# Convert documents to feature vectors by averaging word embeddings
def document_vector(tokens, model):
    vectors = [model.wv[word] for word in tokens if word in model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

# Create document embeddings
df["doc_vector"] = df["tokens"].map(lambda x: document_vector(x, w2v_model))

# Stack document vectors into a matrix
X = np.vstack(df["doc_vector"].values)

# Apply K-Means clustering
num_clusters = 3 # Adjust based on your dataset
kmeans = MiniBatchKMeans(n_clusters=num_clusters, random_state=42, n_init=10)
df["cluster"] = kmeans.fit_predict(X)

# Print results
print(df[["text", "cluster"]])

# Save clustered dataset
df.to_csv("clustered_data.csv", index=False)
# Out:
#                                                   text  cluster
# 0    [{'role': 'user', 'content': 'What are the mai...        9
# 1    [{'role': 'user', 'content': 'What is employee...        6
# 2    [{'role': 'user', 'content': 'Where is the hea...        0
# 3    [{'role': 'user', 'content': 'What happens whe...        9
# 4    [{'role': 'user', 'content': 'How can I instal...        9
# ..                                                 ...      ...
# 139  [{'role': 'user', 'content': 'What is the main...        9
# 140  [{'role': 'user', 'content': 'What actions hav...        0
# 141  [{'role': 'user', 'content': 'What does Lyon A...        0
# 142  [{'role': 'user', 'content': "What is Lyon Aér...        0
# 143  [{'role': 'user', 'content': "What is Lyon air...        9
#
# [144 rows x 2 columns]

# %%
# Sort the dataframe by cluster labels
df_sorted = df.sort_values(by="cluster")

# Display a few sample rows from each cluster
for cluster in range(num_clusters):
    print(f"Cluster {cluster}:")
    display(df_sorted[df_sorted["cluster"] == cluster].head(5))
    print("\n")
# Out:
# Cluster 0:
#                                                history  \
# 98   [{'role': 'user', 'content': 'What should I do...
# 100  [{'role': 'user', 'content': 'Is this service ...
# 91   [{'role': 'user', 'content': 'How can I get fr...
# 95   [{'role': 'user', 'content': 'Who manages the ...
# 93   [{'role': 'user', 'content': 'Where is the Air...
#
#                               question  \
# 98       And if my baggage is damaged?
# 100               Where is it located?
# 91   What about traveling to the Alps?
# 95      Where is their office located?
# 93      What about the other airlines?
#
#                                query_modifier_question  \
# 98   What should I do if my baggage is damaged at L...
# 100                      Where is the service located?
# 91   What are the travel options from Lyon Airport ...
# 95   Where is Alyzia's office for Easyjet baggage s...
# 93   What is the location of baggage services for o...
#
#                                       generated_answer  \
# 98   If your baggage is damaged at Lyon Airport, re...
# 100  I am unable to provide the location of the ser...
# 91   From Lyon Airport, you can travel to the Alps ...
# 95   Alyzia's office for Easyjet baggage service is...
# 93   The baggage service for other airlines is mana...
#
#                                                 answer  \
# 98   If your baggage is damaged, you should seek in...
# 100                    The service is located outside.
# 91   You can travel to the Alps from Lyon Airport w...
# 95   Alyzia's office is located in the baggage clai...
# 93   For Corsair, Easyjet, Royal Air Maroc, Royal J...
#
#                                                   text  \
# 98   [{'role': 'user', 'content': 'What should I do...
# 100  [{'role': 'user', 'content': 'Is this service ...
# 91   [{'role': 'user', 'content': 'How can I get fr...
# 95   [{'role': 'user', 'content': 'Who manages the ...
# 93   [{'role': 'user', 'content': 'Where is the Air...
#
#                                                 tokens  \
# 98   [lose, item, lyon, lose, item, lyon, contact, ...
# 100  [service, service, service, unable, provide, l...
# 91   [lyon, airport, city, connects, lyon, center, ...
# 95   [manages, baggage, service, baggage, service, ...
# 93   [air, france, baggage, service, air, france, b...
#
#                                             doc_vector  cluster
# 98   [3.424577e-05, 0.0043963077, 0.0009705579, -0....        0
# 100  [0.0012432816, 0.0045177033, 0.0021609832, -2....        0
# 91   [0.0008213088, 0.0018248743, 0.0004122288, 0.0...        0
# 95   [0.0016431212, 0.0035506093, -0.00038029862, -...        0
# 93   [0.0016661871, 0.0027206542, 0.0011027243, -0....        0
# Cluster 1:
#                                               history  \
# 82  [{'role': 'user', 'content': "What was the rol...
# 83  [{'role': 'user', 'content': 'What was the Fre...
# 74  [{'role': 'user', 'content': 'What did the emp...
# 22  [{'role': 'user', 'content': 'When was COVID-1...
# 72  [{'role': 'user', 'content': 'Who is mentioned...
#
#                                              question  \
# 82  How many ministerial departments were there du...
# 83    Where was the general headquarters established?
# 74                            What did he order next?
# 22              How did the EU manage to overcome it?
# 72                                  What did he lose?
#
#                               query_modifier_question  \
# 82  How many ministerial departments existed durin...
# 83  Where was the French army's general headquarte...
# 74  What did the emperor order after spreading the...
# 22  How did the European Union manage to overcome ...
# 72                            What did Napoléon lose?
#
#                                      generated_answer  \
# 82  During the French Revolution, there were gener...
# 83  The French army's general headquarters was est...
# 74  Not enough information is available to answer ...
# 22  The European Union overcame COVID-19 through c...
# 72  Napoléon lost his empire, his dynasty, and his...
#
#                                                answer  \
# 82  During the Revolution, there were generally si...
# 83  Napoleon established his general headquarters ...
# 74  He ordered nine battalions of the imperial gua...
# 22  The EU successfully overcame the COVID-19 pand...
# 72  Napoléon lost the three scrutins organized dur...
#
#                                                  text  \
# 82  [{'role': 'user', 'content': "What was the rol...
# 83  [{'role': 'user', 'content': 'What was the Fre...
# 74  [{'role': 'user', 'content': 'What did the emp...
# 22  [{'role': 'user', 'content': 'When was COVID-1...
# 72  [{'role': 'user', 'content': 'Who is mentioned...
#
#                                                tokens  \
# 82  [role, ministers, executors, similar, predeces...
# 83  [french, army, preparing, french, army, prepar...
# 74  [did, emperor, motivate, emperor, spread, rumo...
# 22  [declared, longer, global, health, 5, declared...
# 72  [mentioned, mentioned, did, did, napoléon, nap...
#
#                                            doc_vector  cluster
# 82  [0.0004062135, 0.0012135122, -0.00035362944, 0...        1
# 83  [0.00023241593, 0.0024841188, -0.0003751751, -...        1
# 74  [0.0016922804, 0.00040191793, 0.0015649986, 0....        1
# 22  [-0.00072067423, 0.00068698835, 0.00018260661,...        1
# 72  [-0.0012891497, -0.0036646966, 0.00062188256, ...        1
# Cluster 2:
#                                                history  \
# 73   [{'role': 'user', 'content': 'Where did Wellin...
# 114  [{'role': 'user', 'content': 'What is done to ...
# 62   [{'role': 'user', 'content': 'Where is the Par...
# 102  [{'role': 'user', 'content': 'What can you tel...
#
#                                    question  \
# 73   Where was the rendezvous with Blücher?
# 114                How often are they done?
# 62     Who is the head of state in Austria?
# 102                  What can you do there?
#
#                                query_modifier_question  \
# 73   Where was the rendezvous between Wellington an...
# 114    How often are water quality analyses conducted?
# 62                Who is the head of state of Austria?
# 102     What activities are available in Oslo, Norway?
#
#                                       generated_answer  \
# 73   The rendezvous between Wellington and Blücher ...
# 114  Not enough information is available on how oft...
# 62     The head of state of Austria is the president.
# 102  I'm sorry, I don't have information on activit...
#
#                                                 answer  \
# 73   The rendezvous with Blücher was at Mont-Saint-...
# 114  The analyses are done regularly to ensure the ...
# 62      The president of Austria is the head of state.
# 102  In Oslo, you can walk along the beautiful Karl...
#
#                                                   text  \
# 73   [{'role': 'user', 'content': 'Where did Wellin...
# 114  [{'role': 'user', 'content': 'What is done to ...
# 62   [{'role': 'user', 'content': 'Where is the Par...
# 102  [{'role': 'user', 'content': 'What can you tel...
#
#                                                 tokens  \
# 73   [did, wellington, spend, night, 16th, spent, n...
# 114  [ensure, water, waters, subject, regular, anal...
# 62   [parliament, austria, parliament, austria, loc...
# 102  [tell, capital, modernity, blends, harmoniousl...
#
#                                             doc_vector  cluster
# 73   [-0.00011092736, 0.00030861696, 0.0010849738, ...        2
# 114  [-0.0019102903, 0.00033871067, 0.002851748, 0....        2
# 62   [-0.0010203347, -0.0007945326, -0.0020802882, ...        2
# 102  [-0.0012343333, 0.0027669105, -0.00042199864, ...        2
# Cluster 3:
#                                               history  \
# 20  [{'role': 'user', 'content': 'Why is research ...
# 30  [{'role': 'user', 'content': 'How many EU coun...
# 31  [{'role': 'user', 'content': 'Are all EU count...
# 13  [{'role': 'user', 'content': 'What has the EU ...
# 18  [{'role': 'user', 'content': 'What does EU pol...
#
#                                              question  \
# 20     What does the EU aim to create for businesses?
# 30                          Which countries are they?
# 31                          Do they all use the euro?
# 13     What percentage of internet users shop online?
# 18  What is crucial for Europe's economic prosperity?
#
#                               query_modifier_question  \
# 20  What does the EU aim to create for businesses ...
# 30                   Which EU countries use the euro?
# 31  Do all EU countries in the Economic and Moneta...
# 13  What percentage of internet users in the EU sh...
# 18  What is crucial for Europe's economic prosperi...
#
#                                      generated_answer  \
# 20  The EU aims to create a business-friendly mark...
# 30  The EU countries that use the euro are Austria...
# 31  No, not all EU countries in the Economic and M...
# 13  In the European Union, 74% of internet users a...
# 18  According to EU policy, a strong industrial ba...
#
#                                                answer  \
# 20  The EU aims to create a business-friendly envi...
# 30  The countries using the euro are Austria, Belg...
# 31  No, only 20 of the EU countries have replaced ...
# 13  74% of internet users aged 16 to 74 in the EU ...
# 18  Europe's long-term economic prosperity will de...
#
#                                                  text  \
# 20  [{'role': 'user', 'content': 'Why is research ...
# 30  [{'role': 'user', 'content': 'How many EU coun...
# 31  [{'role': 'user', 'content': 'Are all EU count...
# 13  [{'role': 'user', 'content': 'What has the EU ...
# 18  [{'role': 'user', 'content': 'What does EU pol...
#
#                                                tokens  \
# 20  [research, innovation, important, innovation, ...
# 30  [eu, countries, use, 20, 27, eu, member, count...
# 31  [eu, countries, economic, monetary, eu, countr...
# 13  [eu, protect, individual, rights, eu, taken, s...
# 18  [does, eu, policy, aim, achieve, business, pol...
#
#                                            doc_vector  cluster
# 20  [-0.0020379203, 0.0021515177, -0.0028335708, 0...        3
# 30  [-0.0021190848, 0.0057171024, 0.0006055456, 0....        3
# 31  [0.0004084427, 0.0048963246, 0.0001506656, -0....        3
# 13  [-0.0022266307, 0.0014406458, 0.0013517067, -0...        3
# 18  [0.00012732527, 0.0011787893, -0.0015442024, -...        3
# Cluster 4:
#                                                history  \
# 125  [{'role': 'user', 'content': 'What is the focu...
#
#                                  question  \
# 125  How many neighborhoods are involved?
#
#                                query_modifier_question  \
# 125  How many neighborhoods in Lyon are involved in...
#
#                                       generated_answer  \
# 125  In Lyon, 18 neighborhoods are involved in urba...
#
#                                                 answer  \
# 125  There are 18 neighborhoods in 7 districts of L...
#
#                                                   text  \
# 125  [{'role': 'user', 'content': 'What is the focu...
#
#                                                 tokens  \
# 125  [focus, urban, policy, urban, policy, lyon, fo...
#
#                                             doc_vector  cluster
# 125  [-0.0015331163, 0.0037142036, -0.00024300917, ...        4
# Cluster 5:
#                                               history  \
# 63  [{'role': 'user', 'content': 'What is the offi...
# 28  [{'role': 'user', 'content': 'What are the ben...
# 29  [{'role': 'user', 'content': 'What are some be...
# 33  [{'role': 'user', 'content': "What is the euro...
# 32  [{'role': 'user', 'content': 'Which country ha...
#
#                                              question  \
# 63                               What is its capital?
# 28                     How does it affect businesses?
# 29                 How does it help with cooperation?
# 33  Which regions use it as an official or de fact...
# 32                                What did they keep?
#
#                               query_modifier_question  \
# 63     What is the capital of the Kingdom of Belgium?
# 28               How does the euro affect businesses?
# 29  How does the euro zone economy promote coopera...
# 33  Which regions outside the EU use the euro as a...
# 32  What currency did Denmark keep after opting ou...
#
#                                      generated_answer  \
# 63  The capital of the Kingdom of Belgium is Bruss...
# 28  The euro benefits businesses by saving costs a...
# 29  The euro zone economy promotes cooperation by ...
# 33  Regions outside the EU using the euro as an of...
# 32  Not enough information is available to answer ...
#
#                                                answer  \
# 63                The capital of Belgium is Brussels.
# 28  The euro makes it easier, cheaper, and safer f...
# 29  The euro is a key mechanism for maximizing the...
# 33  Regions like the Azores, Madeira, Canary Islan...
# 32                  Denmark kept its former currency.
#
#                                                  text  \
# 63  [{'role': 'user', 'content': 'What is the offi...
# 28  [{'role': 'user', 'content': 'What are the ben...
# 29  [{'role': 'user', 'content': 'What are some be...
# 33  [{'role': 'user', 'content': "What is the euro...
# 32  [{'role': 'user', 'content': 'Which country ha...
#
#                                                tokens  \
# 63  [official, official, belgium, kingdom, capital...
# 28  [benefits, euro, offers, benefits, economies, ...
# 29  [benefits, euro, zone, euro, zone, economy, be...
# 33  [significance, outside, euro, euro, second, im...
# 32  [country, euro, kept, currency, member, did, c...
#
#                                            doc_vector  cluster
# 63  [0.0009106346, 0.0072047743, 0.0032897806, -0....        5
# 28  [-0.0016184072, 0.0020378316, 0.00023083098, -...        5
# 29  [-0.0034273386, 0.0020923198, 0.0031368043, -0...        5
# 33  [0.0006708014, 0.0033122818, 0.00044479186, -0...        5
# 32  [-0.0011779668, 0.004747417, 0.004969182, 0.00...        5
# Cluster 6:
#                                                history  \
# 1    [{'role': 'user', 'content': 'What is employee...
# 105  [{'role': 'user', 'content': 'What can you do ...
# 58   [{'role': 'user', 'content': 'What was the pol...
# 57   [{'role': 'user', 'content': 'Who is known as ...
# 106  [{'role': 'user', 'content': 'What makes Edinb...
#
#                                               question  \
# 1    How did it help against Vincent Bolloré's atte...
# 105                  What about the surrounding areas?
# 58   How did other Greek city-states compare to Ath...
# 57                            What did he write about?
# 106            What can you do there during Halloween?
#
#                                query_modifier_question  \
# 1    How did employee shareholding at Bouygues help...
# 105  What Halloween activities are available in the...
# 58   What was the government structure of other Gre...
# 57                     What did Herodotus write about?
# 106  What activities are available in Edinburgh dur...
#
#                                       generated_answer  \
# 1    In 1998, Bouygues' employee shareholding helpe...
# 105  In the areas surrounding Bucharest, you can ve...
# 58   During the Archaic period, many Greek city-sta...
# 57   Herodotus wrote 'The Histories, ' which provid...
# 106  In Edinburgh during Halloween, visitors can ex...
#
#                                                 answer  \
# 1    The employee shareholding helped counter Vince...
# 105  For a full experience, you can venture to Tran...
# 58   While Athens established a democracy, other Gr...
# 57   Herodotus wrote about historical figures such ...
# 106  In Edinburgh, you can join guided tours at nig...
#
#                                                   text  \
# 1    [{'role': 'user', 'content': 'What is employee...
# 105  [{'role': 'user', 'content': 'What can you do ...
# 58   [{'role': 'user', 'content': 'What was the pol...
# 57   [{'role': 'user', 'content': 'Who is known as ...
# 106  [{'role': 'user', 'content': 'What makes Edinb...
#
#                                                 tokens  \
# 1    [employee, shareholding, bouygues, developed, ...
# 105  [bucharest, explore, historic, walk, illuminat...
# 58   [political, structure, athens, archaic, archai...
# 57   [known, father, widely, known, father, did, wr...
# 106  [makes, edinburgh, special, capital, brings, h...
#
#                                             doc_vector  cluster
# 1    [0.0019775215, -2.6104195e-05, 0.0016660707, 0...        6
# 105  [-0.00041690658, 0.0011111564, 0.00078685425, ...        6
# 58   [-0.0020245332, 0.0007417745, 0.0024070898, 0....        6
# 57   [0.0024846033, 0.0011428737, 0.0019468028, 0.0...        6
# 106  [0.00038702274, 0.00055652007, 0.00347425, 0.0...        6
# Cluster 7:
#                                                history  \
# 133  [{'role': 'user', 'content': 'How many passeng...
# 116  [{'role': 'user', 'content': 'What is the ener...
# 132  [{'role': 'user', 'content': 'Who operates the...
#
#                                question  \
# 133  And how many movements were there?
# 116          What was the initial goal?
# 132       When does the concession end?
#
#                                query_modifier_question  \
# 133  How many aircraft movements were there at Atla...
# 116  What was the initial energy savings goal of th...
# 132  When does VINCI Airports' concession for opera...
#
#                                       generated_answer  \
# 133  Not enough information is available to determi...
# 116  The initial energy savings goal of the City of...
# 132  The operating contract for Atlantic City Inter...
#
#                                                 answer  \
# 133  There were 8,109 movements at the Atlantic Cit...
# 116  The initial goal was to achieve 10% energy sav...
# 132  The concession for the Atlantic City Internati...
#
#                                                   text  \
# 133  [{'role': 'user', 'content': 'How many passeng...
# 116  [{'role': 'user', 'content': 'What is the ener...
# 132  [{'role': 'user', 'content': 'Who operates the...
#
#                                                 tokens  \
# 133  [passengers, did, atlantic, city, internationa...
# 116  [energy, saving, plan, city, energy, saving, p...
# 132  [operates, atlantic, city, international, airp...
#
#                                             doc_vector  cluster
# 133  [0.0010982389, -0.00047543034, 0.0013788722, -...        7
# 116  [0.0016732686, 0.0020316998, 0.0039005126, -0....        7
# 132  [0.0010492854, -0.0014025162, 0.0005625584, -0...        7
# Cluster 8:
#                                                history  \
# 129  [{'role': 'user', 'content': 'Can you tell me ...
# 134  [{'role': 'user', 'content': 'Can you tell me ...
# 135  [{'role': 'user', 'content': 'Can you tell me ...
#
#                                  question  \
# 129  What about the airports in Portugal?
# 134                 What about in Brazil?
# 135      What about airports in Portugal?
#
#                  query_modifier_question  \
# 129  What are some airports in Portugal?
# 134    What are some airports in Brazil?
# 135  What are some airports in Portugal?
#
#                                       generated_answer  \
# 129  Some airports in Portugal include Aéroport de ...
# 134  Brazil has several airports, including Aéropor...
# 135  Portugal has several airports, including Aérop...
#
#                                                 answer  \
# 129  In Portugal, there are several airports such a...
# 134  In Brazil, there are airports like Tefé Airpor...
# 135  In Portugal, there are airports like Aéroport ...
#
#                                                   text  \
# 129  [{'role': 'user', 'content': 'Can you tell me ...
# 134  [{'role': 'user', 'content': 'Can you tell me ...
# 135  [{'role': 'user', 'content': 'Can you tell me ...
#
#                                                 tokens  \
# 129  [tell, airports, airports, including, aéroport...
# 134  [tell, airports, united, airports, united, inc...
# 135  [tell, airports, airports, france, aéroport, p...
#
#                                             doc_vector  cluster
# 129  [-0.004776806, 0.004311443, 0.0027643198, 0.00...        8
# 134  [-0.0027654788, 0.0039025743, -0.0013099692, 0...        8
# 135  [-0.0048060925, 0.0047085225, 0.00311829, 0.00...        8
# Cluster 9:
#                                                history  \
# 97   [{'role': 'user', 'content': 'What can I bring...
# 96   [{'role': 'user', 'content': 'What should I be...
# 101  [{'role': 'user', 'content': 'Can I recharge m...
# 99   [{'role': 'user', 'content': 'Is the parking o...
# 0    [{'role': 'user', 'content': 'What are the mai...
#
#                                               question  \
# 97   What if I forget to leave something prohibited...
# 96           Where can I find the estimated wait time?
# 101  What should I bring to use the charging stations?
# 99                                Where is it located?
# 0             What other sectors are they involved in?
#
#                                query_modifier_question  \
# 97   What happens if prohibited items are found in ...
# 96   Where can I find the estimated wait time for a...
# 101  What is required to use the electric vehicle c...
# 99                       Where is the parking located?
# 0    What other sectors is Bouygues involved in bes...
#
#                                       generated_answer  \
# 97   If prohibited items are found in luggage, Lyon...
# 96   You can find the estimated wait time for airpo...
# 101  To use the electric vehicle charging stations ...
# 99   The parking is located in an exterior zone and...
# 0    Besides construction, real estate, media, and ...
#
#                                                 answer  \
# 97   If you forget to leave a prohibited item at ho...
# 96   You can find the estimated wait time for secur...
# 101  You need to bring your own adapter to use the ...
# 99   The parking is located at Parking P3 at Lyon A...
# 0    Besides construction and real estate, Bouygues...
#
#                                                   text  \
# 97   [{'role': 'user', 'content': 'What can I bring...
# 96   [{'role': 'user', 'content': 'What should I be...
# 101  [{'role': 'user', 'content': 'Can I recharge m...
# 99   [{'role': 'user', 'content': 'Is the parking o...
# 0    [{'role': 'user', 'content': 'What are the mai...
#
#                                                 tokens  \
# 97   [bring, check, dgac, website, information, pro...
# 96   [aware, regarding, security, checks, aware, de...
# 101  [recharge, electric, vehicle, lyon, recharge, ...
# 99   [parking, open, parking, open, 7, days, parkin...
# 0    [main, business, activities, main, business, a...
#
#                                             doc_vector  cluster
# 97   [-0.0010920127, 0.0023740272, -0.0024049792, -...        9
# 96   [0.0016338062, 0.002085438, 0.0025325192, 0.00...        9
# 101  [0.0010020903, 0.005290419, -0.00027900992, 0....        9
# 99   [0.0011880384, 0.0034522908, 0.002829211, 0.00...        9
# 0    [-0.0015435533, 0.0016477973, -0.0029323648, -...        9
